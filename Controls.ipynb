# %% [markdown]
# import os
# from SchemaValidator import SchemaValidator
# from SyntaxValidator import SyntaxValidator
#
# schemaValidator = SchemaValidator()
# syntaxValidator = SyntaxValidator()
#
# # The directory with XML files
# XML_DIR = os.getcwd() + '\\XML\\UBL\\'
#
# for file_name in os.listdir(XML_DIR):
#     schV = 0
#     synV = 0
#     pepV = 0
#     print('{}: '.format(file_name), end='')
#
#     file_path = '{}/{}'.format(XML_DIR, file_name)
#     schemaValidator.setDocType('INV')
#     if schemaValidator.validate(file_path):
#         #print('Valid')
#         schV = 1
#     else:
#         #print('Not valid')
#         schV = 0
#     syntaxValidator.generateOutputFile(file_path, 'UBL')
#     if syntaxValidator.validate('UBL'):
#         #print('Valid')
#         synV = 1
#     else:
#         #print('Not valid')
#         synV = 0
#
#     syntaxValidator.generateOutputFile(file_path, 'PEPPOL')
#     if syntaxValidator.validate('PEPPOL'):
#         #print('Valid')
#         peppolV = 1
#     else:
#         #print('Not valid')
#         peppolV = 0
#
#     if (schV == 1 & synV == 1 & peppolV == 1):
#         print('Valid')
#     else:
#         print('Invalid')

# %%
from Controller import Controller
control = Controller()
control.validateFiles()
# Out:
# EDIFACTINT_INVOIC_1_20130417_0906_5559.ubl: Valid
# EDIFACTINT_INVOIC_1_20130418_1116_5579.ubl: Valid
# EDIFACTINT_INVOIC_1_20130425_1406_5673.ubl: Valid
# EDIFACTINT_INVOIC_1_20130430_1013_5721.ubl: Valid
# EDIFACTINT_INVOIC_1_20130502_1212_5753.ubl: Valid
# EDIFACTINT_INVOIC_1_20130503_1226_5770.ubl: Valid
# EDIFACTINT_INVOIC_1_20130506_1250_5787.ubl: Valid
# EDIFACTINT_INVOIC_1_20130507_0929_5800.ubl: Valid
# EDIFACTINT_INVOIC_1_20130514_1208_5842.ubl: Valid
# EDIFACTINT_INVOIC_1_20130515_1114_5850.ubl: Valid
# EDIFACTINT_INVOIC_1_20130521_1503_5925.ubl: Valid
# EDIFACTINT_INVOIC_1_20130523_1213_5957.ubl: Valid
# EDIFACTINT_INVOIC_1_20130527_1136_5991.ubl: Valid
# EDIFACTINT_INVOIC_1_20130527_1704_6009.ubl: Valid
# EDIFACTINT_INVOIC_1_20130528_0944_6012.ubl: Valid
# EDIFACTINT_INVOIC_1_20130529_1113_6035.ubl: Valid
# EDIFACTINT_INVOIC_1_20130603_1220_6095.ubl: Valid
# EDIFACTINT_INVOIC_1_20130607_1400_6163.ubl: Valid
# EDIFACTINT_INVOIC_1_20130610_1113_6174.ubl: Valid
# EDIFACTINT_INVOIC_1_20130611_1110_6191.ubl: Valid
# EDIFACTINT_INVOIC_1_20130613_1211_6234.ubl: Valid
# EDIFACTINT_INVOIC_1_20130614_1104_6246.ubl: Valid
# EDIFACTINT_INVOIC_1_20130617_1118_6264.ubl: Valid
# EDIFACTINT_INVOIC_1_20130619_1107_6296.ubl: Valid
# EDIFACTINT_INVOIC_1_20130620_1110_6314.ubl: Valid
# EDIFACTINT_INVOIC_1_20130624_1136_6346.ubl: Valid
# EDIFACTINT_INVOIC_1_20130625_1227_6369.ubl: Valid
# EDIFACTINT_INVOIC_1_20130626_1133_6381.ubl: Valid
# EDIFACTINT_INVOIC_1_20130627_1124_6402.ubl: Valid
# EDIFACTINT_INVOIC_1_20130702_1223_6456.ubl: Valid
# EDIFACTINT_INVOIC_1_20130703_1116_6468.ubl: Valid
# EDIFACTINT_INVOIC_1_20130704_1157_6493.ubl: Valid
# EDIFACTINT_INVOIC_1_20130705_1218_6508.ubl: Valid
# EDIFACTINT_INVOIC_1_20130709_1211_6537.ubl: Valid
# EDIFACTINT_INVOIC_1_20130710_1111_6549.ubl: Valid
# EDIFACTINT_INVOIC_1_20130711_1209_6570.ubl: Valid
# EDIFACTINT_INVOIC_1_20130712_1144_6587.ubl: Valid
# EDIFACTINT_INVOIC_1_20130715_1059_6597.ubl: Valid
# EDIFACTINT_INVOIC_1_20130716_1204_6620.ubl: Valid
# EDIFACTINT_INVOIC_1_20130718_1559_6656.ubl: Valid
# EDIFACTINT_INVOIC_1_20130719_1359_6666.ubl: Valid
# EDIFACTINT_INVOIC_1_20130722_1114_6673.ubl: Valid
# EDIFACTINT_INVOIC_1_20130723_0959_6689.ubl: Valid
# EDIFACTINT_INVOIC_1_20130724_1109_6703.ubl: Valid
# EDIFACTINT_INVOIC_1_20130726_1050_6729.ubl: Valid
# EDIFACTINT_INVOIC_1_20130827_1614_6871.ubl: Valid
# EDIFACTINT_INVOIC_1_20130827_1654_6872.ubl: Valid
# EDIFACTINT_INVOIC_1_20130828_1517_6895.ubl: Valid
# EDIFACTINT_INVOIC_1_20130902_1014_6935.ubl: Valid
# EDIFACTINT_INVOIC_1_20130904_0937_6964.ubl: Valid
# EDIFACTINT_INVOIC_1_20130917_1209_7115.ubl: Valid
# EDIFACTINT_INVOIC_1_20130919_1209_7147.ubl: Valid
# EDIFACTINT_INVOIC_1_20130920_1206_7156.ubl: Valid
# EDIFACTINT_INVOIC_1_20130924_1203_7197.ubl: Valid
# EDIFACTINT_INVOIC_1_20130925_1002_7207.ubl: Valid
# EDIFACTINT_INVOIC_1_20130926_1223_7235.ubl: Valid
# EDIFACTINT_INVOIC_1_20130927_1108_7244.ubl: Valid
# EDIFACTINT_INVOIC_1_20130930_1155_7262.ubl: Valid
# EDIFACTINT_INVOIC_1_20131002_1139_7294.ubl: Valid
# EDIFACTINT_INVOIC_1_20131003_1022_7309.ubl: Valid
# EDIFACTINT_INVOIC_1_20131004_1203_7328.ubl: Valid
# EDIFACTINT_INVOIC_1_20131007_1105_7339.ubl: Valid
# EDIFACTINT_INVOIC_1_20131008_1111_7357.ubl: Valid
# EDIFACTINT_INVOIC_1_20131010_1201_7404.ubl: Valid
# EDIFACTINT_INVOIC_1_20131011_1126_7414.ubl: Valid
# EDIFACTINT_INVOIC_1_20131014_1102_7432.ubl: Valid
# EDIFACTINT_INVOIC_1_20131015_1216_7458.ubl: Valid
# EDIFACTINT_INVOIC_1_20131016_1341_7475.ubl: Valid
# EDIFACTINT_INVOIC_1_20131017_1502_7497.ubl: Valid
# EDIFACTINT_INVOIC_1_20131018_1508_7511.ubl: Valid
# EDIFACTINT_INVOIC_1_20131022_1143_7533.ubl: Valid
# EDIFACTINT_INVOIC_1_20131023_1142_7549.ubl: Valid
# EDIFACTINT_INVOIC_1_20131024_1055_7566.ubl: Valid
# EDIFACTINT_INVOIC_1_20131030_1125_7619.ubl: Valid
# EDIFACTINT_INVOIC_1_20131104_1147_7648.ubl: Valid
# EDIFACTINT_INVOIC_1_20131105_1101_7665.ubl: Valid
# EDIFACTINT_INVOIC_1_20131106_1006_7680.ubl: Valid
# EDIFACTINT_INVOIC_1_20131112_1414_7737.ubl: Valid
# EDIFACTINT_INVOIC_1_20131113_1412_7752.ubl: Valid
# EDIFACTINT_INVOIC_1_20131114_1713_7773.ubl: Valid
# EDIFACTINT_INVOIC_1_20131115_1538_7789.ubl: Valid
# EDIFACTINT_INVOIC_1_20131118_0959_7792.ubl: Valid
# EDIFACTINT_INVOIC_1_20131119_0951_7810.ubl: Valid
# EDIFACTINT_INVOIC_1_20131126_0959_7881.ubl: Valid
# EDIFACTINT_INVOIC_1_20131126_1206_7902.ubl: Valid
# EDIFACTINT_INVOIC_1_20131127_1620_7926.ubl: Valid
# EDIFACTINT_INVOIC_1_20131128_1104_7935.ubl: Valid
# EDIFACTINT_INVOIC_1_20131129_1146_7954.ubl: Valid
# EDIFACTINT_INVOIC_1_20131202_1205_7980.ubl: Valid
# EDIFACTINT_INVOIC_1_20131203_1117_7991.ubl: Valid
# EDIFACTINT_INVOIC_1_20131204_1123_8009.ubl: Valid
# EDIFACTINT_INVOIC_1_20131205_1147_8024.ubl: Valid
# EDIFACTINT_INVOIC_1_20131209_1405_8065.ubl: Valid
# EDIFACTINT_INVOIC_1_20131210_1056_8073.ubl: Valid
# EDIFACTINT_INVOIC_1_20131211_1400_8100.ubl: Valid
# EDIFACTINT_INVOIC_1_20131213_1044_8126.ubl: Valid
# EDIFACTINT_INVOIC_1_20131216_1127_8145.ubl: Valid
# EDIFACTINT_INVOIC_1_20131217_1224_8168.ubl: Valid
# EDIFACTINT_INVOIC_1_20131218_1142_8179.ubl: Valid
# EDIFACTINT_INVOIC_1_20131219_1601_8201.ubl: Valid
# EDIFACTINT_INVOIC_1_20140115_1214_8356.ubl: Valid
# EDIFACTINT_INVOIC_1_20140117_1102_8394.ubl: Valid
# EDIFACTINT_INVOIC_1_20140120_1139_8409.ubl: Valid
# EDIFACTINT_INVOIC_1_20140122_1115_8447.ubl: Valid
# EDIFACTINT_INVOIC_1_20140123_1104_8462.ubl: Valid
# EDIFACTINT_INVOIC_1_20140124_1124_8477.ubl: Valid
# EDIFACTINT_INVOIC_1_20140127_1011_8492.ubl: Valid
# EDIFACTINT_INVOIC_1_20140129_1057_8524.ubl: Valid
# EDIFACTINT_INVOIC_1_20140130_1052_8544.ubl: Valid
# EDIFACTINT_INVOIC_1_20140203_1037_8578.ubl: Valid
# EDIFACTINT_INVOIC_1_20140203_1138_8585.ubl: Valid
# EDIFACTINT_INVOIC_1_20140206_1056_8630.ubl: Valid
# EDIFACTINT_INVOIC_1_20140207_1019_8646.ubl: Valid
# EDIFACTINT_INVOIC_1_20140210_1546_8674.ubl: Valid
# EDIFACTINT_INVOIC_1_20140211_1350_8691.ubl: Valid
# EDIFACTINT_INVOIC_1_20140212_1159_8704.ubl: Valid
# EDIFACTINT_INVOIC_1_20140212_1408_8709.ubl: Valid
# EDIFACTINT_INVOIC_1_20140214_1211_8745.ubl: Valid
# EDIFACTINT_INVOIC_1_20140217_1121_8757.ubl: Valid
# EDIFACTINT_INVOIC_1_20140218_1110_8778.ubl: Valid
# EDIFACTINT_INVOIC_1_20140219_1104_8795.ubl: Valid
# EDIFACTINT_INVOIC_1_20140220_1112_8813.ubl: Valid
# EDIFACTINT_INVOIC_1_20140221_1120_8832.ubl: Valid
# EDIFACTINT_INVOIC_1_20140225_1137_8864.ubl: Valid
# EDIFACTINT_INVOIC_1_20140227_1604_8906.ubl: Valid
# EDIFACTINT_INVOIC_1_20140303_1108_8931.ubl: Valid
# EDIFACTINT_INVOIC_1_20140304_1021_8953.ubl: Valid
# EDIFACTINT_INVOIC_1_20140305_1020_8970.ubl: Valid
# EDIFACTINT_INVOIC_1_20140310_1123_9022.ubl: Valid
# EDIFACTINT_INVOIC_1_20140310_1431_9034.ubl: Valid
# EDIFACTINT_INVOIC_1_20140311_1033_9044.ubl: Valid
# EDIFACTINT_INVOIC_1_20140312_1049_9061.ubl: Valid
# EDIFACTINT_INVOIC_1_20140317_1422_9126.ubl: Valid
# EDIFACTINT_INVOIC_1_20140319_1054_9149.ubl: Valid
# EDIFACTINT_INVOIC_1_20140319_1140_9154.ubl: Valid
# EDIFACTINT_INVOIC_1_20140324_1420_9213.ubl: Valid
# EDIFACTINT_INVOIC_1_20140325_1127_9222.ubl: Valid
# EDIFACTINT_INVOIC_1_20140326_1110_9239.ubl: Valid
# EDIFACTINT_INVOIC_1_20140408_1600_9392.ubl: Valid
# EDIFACTINT_INVOIC_1_20140409_1035_9397.ubl: Valid
# EDIFACTINT_INVOIC_1_20140410_1428_9427.ubl: Valid
# EDIFACTINT_INVOIC_1_20140410_1435_9428.ubl: Valid
# EDIFACTINT_INVOIC_1_20140415_1835_9476.ubl: Valid
# EDIFACTINT_INVOIC_1_20140418_1445_9520.ubl: Valid
# EDIFACTINT_INVOIC_1_20140428_1411_9579.ubl: Valid
# EDIFACTINT_INVOIC_1_20140429_1655_9606.ubl: Valid
# EDIFACTINT_INVOIC_1_20140513_1441_9738.ubl: Valid
# EDIFACTINT_INVOIC_1_20140602_1106_9965.ubl: Valid
# EDIFACTINT_INVOIC_1_20140606_1846_38.ubl: Valid
# EDIFACTINT_INVOIC_1_20140611_1003_60.ubl: Valid
# EDIFACTINT_INVOIC_1_20140616_1119_117.ubl: Valid
# EDIFACTINT_INVOIC_1_20140625_1403_245.ubl: Valid
# EDIFACTINT_INVOIC_1_20140701_1401_312.ubl: Valid
# EDIFACTINT_INVOIC_1_20140707_1202_366.ubl: Valid
# EDIFACTINT_INVOIC_1_20140707_1540_372.ubl: Valid
# EDIFACTINT_INVOIC_1_20140708_1116_386.ubl: Valid
# EDIFACTINT_INVOIC_1_20140710_1544_431.ubl: Valid
# EDIFACTINT_INVOIC_1_20140716_1116_466.ubl: Valid
# EDIFACTINT_INVOIC_1_20140716_1213_474.ubl: Valid
# EDIFACTINT_INVOIC_1_20140717_1031_486.ubl: Valid
# EDIFACTINT_INVOIC_1_20140721_0836_511.ubl: Valid
# EDIFACTINT_INVOIC_1_20140721_1156_519.ubl: Valid
# EDIFACTINT_INVOIC_1_20140722_1041_534.ubl: Valid
# EDIFACTINT_INVOIC_1_20140723_1049_548.ubl: Valid
# EDIFACTINT_INVOIC_1_20140724_1023_565.ubl: Valid
# EDIFACTINT_INVOIC_1_20140901_1412_767.ubl: Valid
# EDIFACTINT_INVOIC_1_20140902_1132_783.ubl: Valid
# EDIFACTINT_INVOIC_1_20140902_1421_798.ubl: Valid
# EDIFACTINT_INVOIC_1_20140908_1431_857.ubl: Valid
# EDIFACTINT_INVOIC_1_20140908_1520_862.ubl: Valid
# EDIFACTINT_INVOIC_1_20140908_1648_873.ubl: Valid
# EDIFACTINT_INVOIC_1_20140909_1107_885.ubl: Valid
# EDIFACTINT_INVOIC_1_20140910_0958_899.ubl: Valid
# EDIFACTINT_INVOIC_1_20140912_1317_943.ubl: Valid
# EDIFACTINT_INVOIC_1_20140915_1101_954.ubl: Valid
# EDIFACTINT_INVOIC_1_20140916_1042_972.ubl: Valid
# EDIFACTINT_INVOIC_1_20140917_1002_988.ubl: Valid
# EDIFACTINT_INVOIC_1_20140918_1401_1014.ubl: Valid
# EDIFACTINT_INVOIC_1_20140922_1124_1045.ubl: Valid
# EDIFACTINT_INVOIC_1_20140924_1028_1076.ubl: Valid
# EDIFACTINT_INVOIC_1_20140924_1101_1081.ubl: Valid
# EDIFACTINT_INVOIC_1_20140925_1102_1102.ubl: Valid
# EDIFACTINT_INVOIC_1_20140926_1209_1125.ubl: Valid
# EDIFACTINT_INVOIC_1_20140929_1034_1133.ubl: Valid
# EDIFACTINT_INVOIC_1_20140930_1023_1151.ubl: Valid
# EDIFACTINT_INVOIC_1_20141001_1111_1165.ubl: Valid
# EDIFACTINT_INVOIC_1_20141006_1054_1206.ubl: Valid
# EDIFACTINT_INVOIC_1_20141007_1159_1233.ubl: Valid
# EDIFACTINT_INVOIC_1_20141008_1055_1243.ubl: Valid
# EDIFACTINT_INVOIC_1_20141009_1121_1264.ubl: Valid
# EDIFACTINT_INVOIC_1_20141010_1004_1278.ubl: Valid
# EDIFACTINT_INVOIC_1_20141013_1152_1296.ubl: Valid
# EDIFACTINT_INVOIC_1_20141014_1041_1311.ubl: Valid
# EDIFACTINT_INVOIC_1_20141015_1149_1330.ubl: Valid
# EDIFACTINT_INVOIC_1_20141016_1111_1350.ubl: Valid
# EDIFACTINT_INVOIC_1_20141017_1102_1364.ubl: Valid
# EDIFACTINT_INVOIC_1_20141022_1042_1408.ubl: Valid
# EDIFACTINT_INVOIC_1_20141022_1600_1425.ubl: Valid
# EDIFACTINT_INVOIC_1_20141023_1109_1430.ubl: Valid
# EDIFACTINT_INVOIC_1_20141023_1553_1443.ubl: Valid
# EDIFACTINT_INVOIC_1_20141027_0848_1474.ubl: Valid
# EDIFACTINT_INVOIC_1_20141027_1715_1486.ubl: Valid
# EDIFACTINT_INVOIC_1_20141028_1604_1501.ubl: Valid
# EDIFACTINT_INVOIC_1_20141029_1443_1513.ubl: Valid
# EDIFACTINT_INVOIC_1_20141103_1645_1557.ubl: Valid
# EDIFACTINT_INVOIC_1_20141114_1420_1666.ubl: Valid
# EDIFACTINT_INVOIC_1_20141114_1456_1672.ubl: Valid
# EDIFACTINT_INVOIC_1_20141117_1556_1697.ubl: Valid
# EDIFACTINT_INVOIC_1_20141120_1215_1742.ubl: Valid
# EDIFACTINT_INVOIC_1_20141120_1528_1747.ubl: Valid
# EDIFACTINT_INVOIC_1_20141121_0805_1752.ubl: Valid
# EDIFACTINT_INVOIC_1_20141124_1144_1769.ubl: Valid
# EDIFACTINT_INVOIC_1_20141125_1448_1796.ubl: Valid
# EDIFACTINT_INVOIC_1_20141125_1637_1801.ubl: Valid
# EDIFACTINT_INVOIC_1_20141126_1628_1814.ubl: Valid
# EDIFACTINT_INVOIC_1_20141127_1400_1831.ubl: Valid
# EDIFACTINT_INVOIC_1_20141201_1213_1869.ubl: Valid
# EDIFACTINT_INVOIC_1_20141203_1435_1902.ubl: Valid
# EDIFACTINT_INVOIC_1_20141209_1719_1976.ubl: Valid
# EDIFACTINT_INVOIC_1_20141210_1213_1987.ubl: Valid
# EDIFACTINT_INVOIC_1_20141210_1357_1990.ubl: Valid
# EDIFACTINT_INVOIC_1_20141212_1236_2017.ubl: Valid
# EDIFACTINT_INVOIC_1_20141215_1626_2045.ubl: Valid
# EDIFACTINT_INVOIC_1_20141218_1426_2094.ubl: Valid
# EDIFACTINT_INVOIC_1_20141219_1031_2100.ubl: Valid
# EDIFACTINT_INVOIC_1_20150108_1640_2199.ubl: Valid
# EDIFACTINT_INVOIC_1_20150120_1701_2314.ubl: Valid
# EDIFACTINT_INVOIC_1_20150121_1538_2336.ubl: Valid
# EDIFACTINT_INVOIC_1_20150122_1212_2347.ubl: Valid
# EDIFACTINT_INVOIC_1_20150122_1517_2364.ubl: Valid
# EDIFACTINT_INVOIC_1_20150122_1631_2377.ubl: Valid
# EDIFACTINT_INVOIC_1_20150122_1801_2382.ubl: Valid
# EDIFACTINT_INVOIC_1_20150129_1510_2482.ubl: Valid
# EDIFACTINT_INVOIC_1_20150209_1205_2590.ubl: Valid
# EDIFACTINT_INVOIC_1_20150209_1607_2605.ubl: Valid
# EDIFACTINT_INVOIC_1_20150211_1410_2641.ubl: Valid
# EDIFACTINT_INVOIC_1_20150212_1414_2658.ubl: Valid
# EDIFACTINT_INVOIC_1_20150212_1459_2663.ubl: Valid
# EDIFACTINT_INVOIC_1_20150212_1549_2669.ubl: Valid
# EDIFACTINT_INVOIC_1_20150217_1316_2712.ubl: Valid
# EDIFACTINT_INVOIC_1_20150217_1323_2716.ubl: Valid
# EDIFACTINT_INVOIC_1_20150219_1416_2750.ubl: Valid
# EDIFACTINT_INVOIC_1_20150219_1554_2757.ubl: Valid
# EDIFACTINT_INVOIC_1_20150219_1649_2761.ubl: Valid
# EDIFACTINT_INVOIC_1_20150316_1156_3010.ubl: Valid
# EDIFACTINT_INVOIC_1_20150316_1351_3013.ubl: Valid
# EDIFACTINT_INVOIC_1_20150317_1533_3056.ubl: Valid
# EDIFACTINT_INVOIC_1_20150319_0955_3073.ubl: Valid
# EDIFACTINT_INVOIC_1_20150324_1515_3140.ubl: Valid
# EDIFACTINT_INVOIC_1_20150326_1209_3160.ubl: Valid
# EDIFACTINT_INVOIC_1_20150326_1603_3172.ubl: Valid
# EDIFACTINT_INVOIC_1_20150401_1040_3215.ubl: Valid
# EDIFACTINT_INVOIC_1_20150401_1520_3232.ubl: Valid
# EDIFACTINT_INVOIC_1_20150410_1214_3299.ubl: Valid
# EDIFACTINT_INVOIC_1_20150413_1054_3312.ubl: Valid
# EDIFACTINT_INVOIC_1_20150414_1013_3327.ubl: Valid
# EDIFACTINT_INVOIC_1_20150416_1209_3369.ubl: Valid
# EDIFACTINT_INVOIC_1_20150417_1356_3383.ubl: Valid
# EDIFACTINT_INVOIC_1_20150420_1241_3400.ubl: Valid
# EDIFACTINT_INVOIC_1_20150422_1050_3420.ubl: Valid
# EDIFACTINT_INVOIC_1_20150422_1420_3436.ubl: Valid
# EDIFACTINT_INVOIC_1_20150424_1456_3459.ubl: Valid
# EDIFACTINT_INVOIC_1_20150427_1212_3464.ubl: Valid
# EDIFACTINT_INVOIC_1_20150428_1501_3490.ubl: Valid
# EDIFACTINT_INVOIC_1_20150429_1201_3493.ubl: Valid
# EDIFACTINT_INVOIC_1_20150430_1211_3515.ubl: Valid
# EDIFACTINT_INVOIC_1_20150504_1200_3522.ubl: Valid
# EDIFACTINT_INVOIC_1_20150512_1138_3621.ubl: Valid
# EDIFACTINT_INVOIC_1_20150519_1211_3677.ubl: Valid
# EDIFACTINT_INVOIC_1_20150526_1200_3749.ubl: Valid
# EDIFACTINT_INVOIC_1_20150601_1428_3817.ubl: Valid
# EDIFACTINT_INVOIC_1_20150602_1504_3844.ubl: Valid
# EDIFACTINT_INVOIC_1_20150603_0843_3845.ubl: Valid
# EDIFACTINT_INVOIC_1_20150603_1609_3862.ubl: Valid
# EDIFACTINT_INVOIC_1_20150608_1103_3887.ubl: Valid
# EDIFACTINT_INVOIC_1_20150609_1021_3912.ubl: Valid
# EDIFACTINT_INVOIC_1_20150610_1154_3926.ubl: Valid
# EDIFACTINT_INVOIC_1_20150611_1228_3953.ubl: Valid
# EDIFACTINT_INVOIC_1_20150612_1536_3972.ubl: Valid
# EDIFACTINT_INVOIC_1_20150616_1207_3998.ubl: Valid
# EDIFACTINT_INVOIC_1_20150619_1131_4034.ubl: Valid
# EDIFACTINT_INVOIC_1_20150622_1341_4060.ubl: Valid
# EDIFACTINT_INVOIC_1_20150623_1135_4068.ubl: Valid
# EDIFACTINT_INVOIC_1_20150624_1108_4081.ubl: Valid
# EDIFACTINT_INVOIC_1_20150625_1434_4106.ubl: Valid
# EDIFACTINT_INVOIC_1_20150629_1048_4125.ubl: Valid
# EDIFACTINT_INVOIC_1_20150629_1701_4142.ubl: Valid
# EDIFACTINT_INVOIC_1_20150630_1149_4150.ubl: Valid
# EDIFACTINT_INVOIC_1_20150630_1657_4153.ubl: Valid
# EDIFACTINT_INVOIC_1_20150701_1207_4165.ubl: Valid
# EDIFACTINT_INVOIC_1_20150708_1421_4233.ubl: Valid
# EDIFACTINT_INVOIC_1_20150709_1350_4248.ubl: Valid
# EDIFACTINT_INVOIC_1_20150710_1350_4268.ubl: Valid
# EDIFACTINT_INVOIC_1_20150715_1127_4285.ubl: Valid
# EDIFACTINT_INVOIC_1_20150715_1153_4288.ubl: Valid
# EDIFACTINT_INVOIC_1_20150715_1204_4292.ubl: Valid
# EDIFACTINT_INVOIC_1_20150715_1738_4310.ubl: Valid
# EDIFACTINT_INVOIC_1_20150717_1149_4330.ubl: Valid
# EDIFACTINT_INVOIC_1_20150722_1111_4374.ubl: Valid
# EDIFACTINT_INVOIC_1_20150723_1633_4396.ubl: Valid
# EDIFACTINT_INVOIC_1_20151202_1713_5515.ubl: Valid
# EDIFACTINT_INVOIC_1_20160525_1551_7009.ubl: Valid
# EDIFACTINT_INVOIC_1_20160617_1032_7225.ubl: Valid
# EDIFACTINT_INVOIC_1_20171207_1558_2303.ubl: Valid
# EDIFACTINT_INVOIC_1_20180215_1530_3016.ubl: [BR-S-08-AUNZ]-For each different value of Tax category rate (BT-119) where the Tax category code (BT-118) is "Standard rated", the Tax category taxable amount (BT-116) in a Tax breakdown (BG-23) shall equal the sum of Invoice line net amounts (BT-131) plus the sum of document level charge amounts (BT-99) minus the sum of document level allowance amounts (BT-92) where the Tax category code (BT-151, BT-102, BT-95) is "Standard rated" and the Tax rate (BT-152, BT-103, BT-96) equals the Tax category rate (BT-119).
# [BR-CO-10]-Sum of Invoice line net amount (BT-106) = Σ Invoice line net amount (BT-131).
# Invoice line net amount MUST equal (Invoiced quantity * (Item net price/item price base quantity) + Sum of invoice line charge amount - sum of invoice line allowance amount
# Invalid
# EDIFACTINT_INVOIC_1_20180215_1539_3017.ubl: [BR-S-08-AUNZ]-For each different value of Tax category rate (BT-119) where the Tax category code (BT-118) is "Standard rated", the Tax category taxable amount (BT-116) in a Tax breakdown (BG-23) shall equal the sum of Invoice line net amounts (BT-131) plus the sum of document level charge amounts (BT-99) minus the sum of document level allowance amounts (BT-92) where the Tax category code (BT-151, BT-102, BT-95) is "Standard rated" and the Tax rate (BT-152, BT-103, BT-96) equals the Tax category rate (BT-119).
# [BR-CO-10]-Sum of Invoice line net amount (BT-106) = Σ Invoice line net amount (BT-131).
# Invalid
# EDIFACTINT_INVOIC_1_20180215_1548_3018.ubl: Valid
# EDIFACTINT_INVOIC_1_20180419_1510_3806.ubl: Valid
# EDIFACTINT_INVOIC_1_20181121_1441_5886.ubl: Valid
# EDIFACTINT_INVOIC_1_20190716_1640_8388.ubl: Valid
# EDIFACTINT_INVOIC_1_20190829_1114_8749.ubl: Valid
# EDIFACTINT_INVOIC_2_20080602_1512_6337.ubl: Valid
# EDIFACTINT_INVOIC_2_20080707_1046_6610.ubl: Valid
# EDIFACTINT_INVOIC_2_20080916_1651_6976.ubl: Valid
# EDIFACTINT_INVOIC_2_20081201_1641_7515.ubl: Valid
# EDIFACTINT_INVOIC_2_20090128_1635_7846.ubl: Valid
# EDIFACTINT_INVOIC_2_20090206_1157_7937.ubl: Valid
# EDIFACTINT_INVOIC_2_20090211_1634_7980.ubl: Valid
# EDIFACTINT_INVOIC_2_20090216_1548_8018.ubl: Valid
# EDIFACTINT_INVOIC_2_20090309_0829_8178.ubl: Valid
# EDIFACTINT_INVOIC_2_20090309_1644_8192.ubl: Valid
# EDIFACTINT_INVOIC_2_20090310_1710_8205.ubl: Valid
# EDIFACTINT_INVOIC_2_20090318_1723_8286.ubl: Valid
# EDIFACTINT_INVOIC_2_20090319_1638_8298.ubl: Valid
# EDIFACTINT_INVOIC_2_20090320_1517_8312.ubl: Valid
# EDIFACTINT_INVOIC_2_20090323_1610_8327.ubl: Valid
# EDIFACTINT_INVOIC_2_20090610_1627_9093.ubl: Valid
# EDIFACTINT_INVOIC_2_20090923_1648_81.ubl: Valid
# EDIFACTINT_INVOIC_2_20091029_1644_520.ubl: Valid
# EDIFACTINT_INVOIC_2_20091119_1651_790.ubl: Valid
# EDIFACTINT_INVOIC_2_20091123_1609_829.ubl: Valid
# EDIFACTINT_INVOIC_2_20100106_1654_1288.ubl: Valid
# EDIFACTINT_INVOIC_2_20100120_1406_1464.ubl: Valid
# EDIFACTINT_INVOIC_2_20100217_1735_1856.ubl: Valid
# EDIFACTINT_INVOIC_2_20100223_1544_1931.ubl: Valid
# EDIFACTINT_INVOIC_2_20100408_0858_2498.ubl: Valid
# EDIFACTINT_INVOIC_2_20100413_0907_2560.ubl: Valid
# EDIFACTINT_INVOIC_2_20100510_0904_2958.ubl: Valid
# EDIFACTINT_INVOIC_2_20100520_0850_3105.ubl: Valid
# EDIFACTINT_INVOIC_2_20100820_1420_4172.ubl: Valid
# EDIFACTINT_INVOIC_2_20100917_1012_4516.ubl: Valid
# EDIFACTINT_INVOIC_2_20100921_1617_4574.ubl: Valid
# EDIFACTINT_INVOIC_2_20100922_1613_4596.ubl: Valid
# EDIFACTINT_INVOIC_2_20100924_1522_4631.ubl: Valid
# EDIFACTINT_INVOIC_2_20100927_1433_4650.ubl: Valid
# EDIFACTINT_INVOIC_2_20100928_1538_4669.ubl: Valid
# EDIFACTINT_INVOIC_2_20101005_1515_4766.ubl: Valid
# EDIFACTINT_INVOIC_2_20101007_1203_4793.ubl: Valid
# EDIFACTINT_INVOIC_2_20101125_1004_5410.ubl: Valid
# EDIFACTINT_INVOIC_2_20101221_0917_5731.ubl: Valid
# EDIFACTINT_INVOIC_2_20110202_0913_6228.ubl: Valid
# EDIFACTINT_INVOIC_2_20110203_1744_6276.ubl: Valid
# EDIFACTINT_INVOIC_2_20110209_1637_6354.ubl: Valid
# EDIFACTINT_INVOIC_2_20110209_1650_6359.ubl: Valid
# EDIFACTINT_INVOIC_2_20110216_0941_6441.ubl: Valid
# EDIFACTINT_INVOIC_2_20110216_1649_6459.ubl: Valid
# EDIFACTINT_INVOIC_2_20110218_1504_6498.ubl: Valid
# EDIFACTINT_INVOIC_2_20110228_1626_6611.ubl: Valid
# EDIFACTINT_INVOIC_2_20110303_1719_6686.ubl: Valid
# EDIFACTINT_INVOIC_2_20110310_1731_6784.ubl: Valid
# EDIFACTINT_INVOIC_2_20110315_0842_6826.ubl: Valid
# EDIFACTINT_INVOIC_2_20110323_0808_6948.ubl: Valid
# EDIFACTINT_INVOIC_2_20110324_0831_6967.ubl: Valid
# EDIFACTINT_INVOIC_2_20110328_1606_7018.ubl: Valid
# EDIFACTINT_INVOIC_2_20110331_1714_7070.ubl: Valid
# EDIFACTINT_INVOIC_2_20110404_1737_7105.ubl: Valid
# EDIFACTINT_INVOIC_2_20110406_1658_7152.ubl: Valid
# EDIFACTINT_INVOIC_2_20110408_1425_7194.ubl: Valid
# EDIFACTINT_INVOIC_2_20110414_0850_7251.ubl: Valid
# EDIFACTINT_INVOIC_2_20110415_0943_7275.ubl: Valid
# EDIFACTINT_INVOIC_2_20110415_1504_7298.ubl: Valid
# EDIFACTINT_INVOIC_2_20110502_0958_7420.ubl: Valid
# EDIFACTINT_INVOIC_2_20110502_1105_7429.ubl: Valid
# EDIFACTINT_INVOIC_2_20110502_1111_7434.ubl: Valid
# EDIFACTINT_INVOIC_2_20110502_1131_7452.ubl: Valid
# EDIFACTINT_INVOIC_2_20110505_1345_7536.ubl: Valid
# EDIFACTINT_INVOIC_2_20110505_1445_7548.ubl: Valid
# EDIFACTINT_INVOIC_2_20110509_1522_7586.ubl: Valid
# EDIFACTINT_INVOIC_2_20110516_1236_7687.ubl: Valid
# EDIFACTINT_INVOIC_2_20110519_0755_7731.ubl: Valid
# EDIFACTINT_INVOIC_2_20110523_1443_7792.ubl: Valid
# EDIFACTINT_INVOIC_2_20110525_1448_7832.ubl: Valid
# EDIFACTINT_INVOIC_2_20110526_1400_7852.ubl: Valid
# EDIFACTINT_INVOIC_2_20110530_1406_7889.ubl: Valid
# EDIFACTINT_INVOIC_2_20110601_0744_7907.ubl: Valid
# EDIFACTINT_INVOIC_2_20110609_1346_8011.ubl: Valid
# EDIFACTINT_INVOIC_2_20110609_1454_8016.ubl: Valid
# EDIFACTINT_INVOIC_2_20110615_0808_8063.ubl: Valid
# EDIFACTINT_INVOIC_2_20110615_1518_8086.ubl: Valid
# EDIFACTINT_INVOIC_2_20110622_1346_8185.ubl: Valid
# EDIFACTINT_INVOIC_2_20110622_1400_8189.ubl: Valid
# EDIFACTINT_INVOIC_2_20110624_1344_8227.ubl: Valid
# EDIFACTINT_INVOIC_2_20110629_0802_8265.ubl: Valid
# EDIFACTINT_INVOIC_2_20110629_1324_8280.ubl: Valid
# EDIFACTINT_INVOIC_2_20110701_1305_8313.ubl: Valid
# EDIFACTINT_INVOIC_2_20110705_1231_8352.ubl: Valid
# EDIFACTINT_INVOIC_2_20110706_0857_8360.ubl: Valid
# EDIFACTINT_INVOIC_2_20110706_1520_8381.ubl: Valid
# EDIFACTINT_INVOIC_2_20110708_1251_8417.ubl: Valid
# EDIFACTINT_INVOIC_2_20110711_1301_8437.ubl: Valid
# EDIFACTINT_INVOIC_2_20110719_1429_8533.ubl: Valid
# EDIFACTINT_INVOIC_2_20110720_1321_8554.ubl: Valid
# EDIFACTINT_INVOIC_2_20110722_1306_8589.ubl: Valid
# EDIFACTINT_INVOIC_2_20110725_1259_8614.ubl: Valid
# EDIFACTINT_INVOIC_2_20110727_1435_8654.ubl: Valid
# EDIFACTINT_INVOIC_2_20110907_0821_8927.ubl: Valid
# EDIFACTINT_INVOIC_2_20110922_0831_9107.ubl: Valid
# EDIFACTINT_INVOIC_2_20110923_1003_9127.ubl: Valid
# EDIFACTINT_INVOIC_2_20110930_1035_9227.ubl: Valid
# EDIFACTINT_INVOIC_2_20111003_1350_9254.ubl: Valid
# EDIFACTINT_INVOIC_2_20111007_1229_9327.ubl: Valid
# EDIFACTINT_INVOIC_2_20111007_1321_9333.ubl: Valid
# EDIFACTINT_INVOIC_2_20111012_1333_9394.ubl: Valid
# EDIFACTINT_INVOIC_2_20111013_1421_9425.ubl: Valid
# EDIFACTINT_INVOIC_2_20111014_1349_9457.ubl: Valid
# EDIFACTINT_INVOIC_2_20111017_1151_9469.ubl: Valid
# EDIFACTINT_INVOIC_2_20111019_1229_9522.ubl: Valid
# EDIFACTINT_INVOIC_2_20111103_1242_9687.ubl: Valid
# EDIFACTINT_INVOIC_2_20111205_1014_124.ubl: Valid
# EDIFACTINT_INVOIC_2_20111214_0948_235.ubl: Valid
# EDIFACTINT_INVOIC_2_20111216_1110_280.ubl: Valid
# EDIFACTINT_INVOIC_2_20120104_1314_379.ubl: Valid
# EDIFACTINT_INVOIC_2_20120106_1047_414.ubl: Valid
# EDIFACTINT_INVOIC_2_20120111_1044_464.ubl: Valid
# EDIFACTINT_INVOIC_2_20120113_1517_497.ubl: Valid
# EDIFACTINT_INVOIC_2_20120117_1539_532.ubl: Valid
# EDIFACTINT_INVOIC_2_20120119_0745_552.ubl: Valid
# EDIFACTINT_INVOIC_2_20120120_1127_580.ubl: Valid
# EDIFACTINT_INVOIC_2_20120130_1100_682.ubl: Valid
# EDIFACTINT_INVOIC_2_20120202_1622_743.ubl: Valid
# EDIFACTINT_INVOIC_2_20120207_1326_793.ubl: Valid
# EDIFACTINT_INVOIC_2_20120216_1054_916.ubl: Valid
# EDIFACTINT_INVOIC_2_20120313_0847_1219.ubl: Valid
# EDIFACTINT_INVOIC_2_20120316_0934_1270.ubl: Valid
# EDIFACTINT_INVOIC_2_20120322_1116_1356.ubl: Valid
# EDIFACTINT_INVOIC_2_20120327_0907_1396.ubl: Valid
# EDIFACTINT_INVOIC_2_20120329_1004_1440.ubl: Valid
# EDIFACTINT_INVOIC_2_20120402_0926_1466.ubl: Valid
# EDIFACTINT_INVOIC_2_20120404_0909_1499.ubl: Valid
# EDIFACTINT_INVOIC_2_20120419_1027_1689.ubl: Valid
# EDIFACTINT_INVOIC_2_20120423_0958_1717.ubl: Valid
# EDIFACTINT_INVOIC_2_20120503_0812_1831.ubl: Valid
# EDIFACTINT_INVOIC_2_20120524_1213_2056.ubl: Valid
# EDIFACTINT_INVOIC_2_20120525_1208_2077.ubl: Valid
# EDIFACTINT_INVOIC_2_20120530_0738_2101.ubl: Valid
# EDIFACTINT_INVOIC_2_20120531_0911_2125.ubl: Valid
# EDIFACTINT_INVOIC_2_20120601_0734_2137.ubl: Valid
# EDIFACTINT_INVOIC_2_20120604_0922_2161.ubl: Valid
# EDIFACTINT_INVOIC_2_20120606_0938_2186.ubl: Valid
# EDIFACTINT_INVOIC_2_20120607_0829_2200.ubl: Valid
# EDIFACTINT_INVOIC_2_20120612_0857_2247.ubl: Valid
# EDIFACTINT_INVOIC_2_20120613_1314_2273.ubl: Valid
# EDIFACTINT_INVOIC_2_20120614_0954_2287.ubl: Valid
# EDIFACTINT_INVOIC_2_20120618_1218_2321.ubl: Valid
# EDIFACTINT_INVOIC_2_20120619_1221_2332.ubl: Valid
# EDIFACTINT_INVOIC_2_20120622_1341_2382.ubl: Valid
# EDIFACTINT_INVOIC_2_20120702_0821_2470.ubl: Valid
# EDIFACTINT_INVOIC_2_20120703_0751_2491.ubl: Valid
# EDIFACTINT_INVOIC_2_20120705_0813_2533.ubl: Valid
# EDIFACTINT_INVOIC_2_20120706_0746_2548.ubl: Valid
# EDIFACTINT_INVOIC_2_20120709_0912_2566.ubl: Valid
# EDIFACTINT_INVOIC_2_20120720_0935_2726.ubl: Valid
# EDIFACTINT_INVOIC_2_20120723_1007_2747.ubl: Valid
# EDIFACTINT_INVOIC_2_20120725_0741_2775.ubl: Valid
# EDIFACTINT_INVOIC_2_20120726_0843_2795.ubl: Valid
# EDIFACTINT_INVOIC_2_20120904_1149_3056.ubl: Valid
# EDIFACTINT_INVOIC_2_20120917_1201_3233.ubl: Valid
# EDIFACTINT_INVOIC_2_20120924_0931_3315.ubl: Valid
# EDIFACTINT_INVOIC_2_20120924_1022_3321.ubl: Valid
# EDIFACTINT_INVOIC_2_20121001_0856_3397.ubl: Valid
# EDIFACTINT_INVOIC_2_20121002_1001_3425.ubl: Valid
# EDIFACTINT_INVOIC_2_20121003_0911_3437.ubl: Valid
# EDIFACTINT_INVOIC_2_20121005_1139_3474.ubl: Valid
# EDIFACTINT_INVOIC_2_20121008_1247_3491.ubl: Valid
# EDIFACTINT_INVOIC_2_20121009_0749_3497.ubl: Valid
# EDIFACTINT_INVOIC_2_20121010_1313_3526.ubl: Valid
# EDIFACTINT_INVOIC_2_20121011_1002_3539.ubl: Valid
# EDIFACTINT_INVOIC_2_20121012_0759_3548.ubl: Valid
# EDIFACTINT_INVOIC_2_20121015_1001_3564.ubl: Valid
# EDIFACTINT_INVOIC_2_20121016_0945_3585.ubl: Valid
# EDIFACTINT_INVOIC_2_20121019_0859_3632.ubl: Valid
# EDIFACTINT_INVOIC_2_20121022_0800_3643.ubl: Valid
# EDIFACTINT_INVOIC_2_20121023_1013_3663.ubl: Valid
# EDIFACTINT_INVOIC_2_20121025_1003_3696.ubl: Valid
# EDIFACTINT_INVOIC_2_20121105_1349_3769.ubl: Valid
# EDIFACTINT_INVOIC_2_20121106_1353_3786.ubl: Valid
# EDIFACTINT_INVOIC_2_20121108_0850_3813.ubl: Valid
# EDIFACTINT_INVOIC_2_20121113_0902_3855.ubl: Valid
# EDIFACTINT_INVOIC_2_20121114_0749_3870.ubl: Valid
# EDIFACTINT_INVOIC_2_20121115_1013_3897.ubl: Valid
# EDIFACTINT_INVOIC_2_20121120_0946_3948.ubl: Valid
# EDIFACTINT_INVOIC_2_20121121_0926_3958.ubl: Valid
# EDIFACTINT_INVOIC_2_20121122_1006_3981.ubl: Valid
# EDIFACTINT_INVOIC_2_20121126_0857_4005.ubl: Valid
# EDIFACTINT_INVOIC_2_20121126_0909_4009.ubl: Valid
# EDIFACTINT_INVOIC_2_20121127_0908_4028.ubl: Valid
# EDIFACTINT_INVOIC_2_20121128_1308_4058.ubl: Valid
# EDIFACTINT_INVOIC_2_20121205_0933_4133.ubl: Valid
# EDIFACTINT_INVOIC_2_20121206_1118_4162.ubl: Valid
# EDIFACTINT_INVOIC_2_20121211_1050_4213.ubl: Valid
# EDIFACTINT_INVOIC_2_20121212_1047_4233.ubl: Valid
# EDIFACTINT_INVOIC_2_20121213_1108_4257.ubl: Valid
# EDIFACTINT_INVOIC_2_20121214_1321_4274.ubl: Valid
# EDIFACTINT_INVOIC_2_20121217_0910_4280.ubl: Valid
# EDIFACTINT_INVOIC_2_20121219_0932_4316.ubl: Valid
# EDIFACTINT_INVOIC_2_20121220_1001_4336.ubl: Valid
# EDIFACTINT_INVOIC_2_20130107_1058_4404.ubl: Valid
# EDIFACTINT_INVOIC_2_20130108_1054_4420.ubl: Valid
# EDIFACTINT_INVOIC_2_20130109_1039_4439.ubl: Valid
# EDIFACTINT_INVOIC_2_20130110_1018_4449.ubl: Valid
# EDIFACTINT_INVOIC_2_20130114_0931_4483.ubl: Valid
# EDIFACTINT_INVOIC_2_20130117_1033_4528.ubl: Valid
# EDIFACTINT_INVOIC_2_20130213_0930_4826.ubl: Valid
# EDIFACTINT_INVOIC_2_20130402_0906_5371.ubl: Valid
# EDIFACTINT_INVOIC_2_20130403_1014_5394.ubl: Valid
# EDIFACTINT_INVOIC_2_20130404_1003_5413.ubl: Valid
# EDIFACTINT_INVOIC_2_20130408_0855_5441.ubl: Valid
# EDIFACTINT_INVOIC_2_20130409_0747_5458.ubl: Valid
# EDIFACTINT_INVOIC_2_20130410_0823_5474.ubl: Valid
# EDIFACTINT_INVOIC_2_20130411_0934_5497.ubl: Valid
# EDIFACTINT_INVOIC_2_20130416_0800_5544.ubl: Valid
# EDIFACTINT_INVOIC_2_20130423_1056_5629.ubl: Valid
# EDIFACTINT_INVOIC_2_20130424_1120_5649.ubl: Valid
# EDIFACTINT_INVOIC_2_20130516_0930_5873.ubl: Valid
# EDIFACTINT_INVOIC_2_20130521_1214_5918.ubl: Valid
# EDIFACTINT_INVOIC_2_20130604_0936_6105.ubl: Valid
# EDIFACTINT_INVOIC_2_20130830_1152_6927.ubl: Valid
# EDIFACTINT_INVOIC_2_20130906_1135_6998.ubl: Valid
# EDIFACTINT_INVOIC_2_20130912_1031_7062.ubl: Valid
# EDIFACTINT_INVOIC_2_20131206_1114_8042.ubl: Valid
# EDIFACTINT_INVOIC_2_20131220_1142_8205.ubl: Valid
# EDIFACTINT_INVOIC_2_20140228_1154_8917.ubl: Valid
# EDIFACTINT_INVOIC_2_20140317_1117_9112.ubl: Valid
# EDIFACTINT_INVOIC_2_20140401_1532_9306.ubl: Valid
# EDIFACTINT_INVOIC_2_20140403_1146_9330.ubl: Valid
# EDIFACTINT_INVOIC_2_20140416_1433_9493.ubl: Valid
# EDIFACTINT_INVOIC_2_20140430_1355_9616.ubl: Valid
# EDIFACTINT_INVOIC_2_20140527_1152_9928.ubl: Valid
# EDIFACTINT_INVOIC_2_20140602_1052_9960.ubl: Valid
# EDIFACTINT_INVOIC_2_20140630_1200_292.ubl: Valid
# EDIFACTINT_INVOIC_2_20140725_1003_577.ubl: Valid
# EDIFACTINT_INVOIC_2_20140902_1215_793.ubl: Valid
# EDIFACTINT_INVOIC_2_20140908_1612_869.ubl: Valid
# EDIFACTINT_INVOIC_2_20140919_1110_1026.ubl: Valid
# EDIFACTINT_INVOIC_2_20141201_1107_1855.ubl: Valid
# EDIFACTINT_INVOIC_2_20141201_1129_1859.ubl: Valid
# EDIFACTINT_INVOIC_2_20141204_1545_1924.ubl: Valid
# EDIFACTINT_INVOIC_2_20141212_1420_2024.ubl: Valid
# EDIFACTINT_INVOIC_2_20141215_1626_2046.ubl: Valid
# EDIFACTINT_INVOIC_2_20150121_1410_2331.ubl: Valid
# EDIFACTINT_INVOIC_2_20150122_1428_2357.ubl: Valid
# EDIFACTINT_INVOIC_2_20150122_1547_2369.ubl: Valid
# EDIFACTINT_INVOIC_2_20150123_1601_2401.ubl: Valid
# EDIFACTINT_INVOIC_2_20150123_1635_2408.ubl: Valid
# EDIFACTINT_INVOIC_2_20150128_1652_2458.ubl: Valid
# EDIFACTINT_INVOIC_2_20150129_1414_2472.ubl: Valid
# EDIFACTINT_INVOIC_2_20150317_1207_3041.ubl: Valid
# EDIFACTINT_INVOIC_2_20150323_1654_3127.ubl: Valid
# EDIFACTINT_INVOIC_2_20150415_1133_3341.ubl: Valid
# EDIFACTINT_INVOIC_2_20150507_1216_3589.ubl: Valid
# EDIFACTINT_INVOIC_2_20150513_1211_3645.ubl: Valid
# EDIFACTINT_INVOIC_2_20150519_1417_3683.ubl: Valid
# EDIFACTINT_INVOIC_2_20150521_1142_3710.ubl: Valid
# EDIFACTINT_INVOIC_2_20150522_1218_3737.ubl: Valid
# EDIFACTINT_INVOIC_2_20150527_1218_3773.ubl: Valid
# EDIFACTINT_INVOIC_2_20150601_1452_3823.ubl: Valid
# EDIFACTINT_INVOIC_2_20150601_1733_3829.ubl: Valid
# EDIFACTINT_INVOIC_2_20150612_1206_3959.ubl: Valid
# EDIFACTINT_INVOIC_2_20150626_1207_4121.ubl: Valid
# EDIFACTINT_INVOIC_2_20150715_1212_4297.ubl: Valid
# EDIFACTINT_INVOIC_2_20150722_1111_4375.ubl: Valid
# EDIFACTINT_INVOIC_2_20150724_1414_4402.ubl: Valid
# EDIFACTINT_INVOIC_2_20150901_1545_4644.ubl: Valid
# EDIFACTINT_INVOIC_2_20151014_1644_5086.ubl: Valid
# EDIFACTINT_INVOIC_2_20151103_1614_5262.ubl: Valid
# EDIFACTINT_INVOIC_2_20151217_1717_5640.ubl: Valid
# EDIFACTINT_INVOIC_2_20160310_0855_6294.ubl: Valid
# EDIFACTINT_INVOIC_2_20160404_1003_6506.ubl: Valid
# EDIFACTINT_INVOIC_2_20160404_1545_6520.ubl: Valid
# EDIFACTINT_INVOIC_2_20160518_1417_6923.ubl: Valid
# EDIFACTINT_INVOIC_2_20160602_1136_7074.ubl: Valid
# EDIFACTINT_INVOIC_2_20170824_1623_1168.ubl: Valid
